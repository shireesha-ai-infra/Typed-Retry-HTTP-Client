# %%
import httpx

class SimpleHTTPClient:
    def get(self, url:str) -> dict:
        response = httpx.get(url, timeout=5)

        if response.status_code!=200:
            raise Exception(f"Request failed: {response.status_code}")

        return response.json()

    def post(self, url:str, data:dict) ->dict:
        response = httpx.post(url, json=data, timeout=5)
        return response.json()

# %%
client = SimpleHTTPClient()

data = client.get("https://jsonplaceholder.typicode.com/posts/1")

print(data)
# Out:
# dict

# %%
print(client.post(
    "https://jsonplaceholder.typicode.com/posts",
    {"title": "test"}
))

# %%
## Handling response

def handle_response(response):
    if response.status_code >= 500:
        raise Exception("Server Error")
    
    if response.status_code >= 400:
        raise Exception(f"Client Error : {response.text}")
    
    content_type = response.headers.get("content-type", "")

    if "application/json" in content_type:
        return response.json()
    
    return response.text

# %% [markdown]
# # Understanding Response object

# %%
response = httpx.get("https://jsonplaceholder.typicode.com/posts/1")

# %%
response
# Out:
# <Response [200 OK]>

# %%
type(response)
# Out:
# httpx.Response

# %%
response.status_code
# Out:
# 200

# %%
response.json()
# Out:
# {'userId': 1,
#  'id': 1,
#  'title': 'sunt aut facere repellat provident occaecati excepturi optio reprehenderit',
#  'body': 'quia et suscipit\nsuscipit recusandae consequuntur expedita et cum\nreprehenderit molestiae ut ut quas totam\nnostrum rerum est autem sunt rem eveniet architecto'}

# %%
response.text
# Out:
# '{\n  "userId": 1,\n  "id": 1,\n  "title": "sunt aut facere repellat provident occaecati excepturi optio reprehenderit",\n  "body": "quia et suscipit\\nsuscipit recusandae consequuntur expedita et cum\\nreprehenderit molestiae ut ut quas totam\\nnostrum rerum est autem sunt rem eveniet architecto"\n}'

# %%
response.content
# Out:
# b'{\n  "userId": 1,\n  "id": 1,\n  "title": "sunt aut facere repellat provident occaecati excepturi optio reprehenderit",\n  "body": "quia et suscipit\\nsuscipit recusandae consequuntur expedita et cum\\nreprehenderit molestiae ut ut quas totam\\nnostrum rerum est autem sunt rem eveniet architecto"\n}'

# %%
response.headers
# Out:
# Headers({'date': 'Thu, 16 Apr 2026 14:43:56 GMT', 'content-type': 'application/json; charset=utf-8', 'transfer-encoding': 'chunked', 'connection': 'keep-alive', 'access-control-allow-credentials': 'true', 'cache-control': 'max-age=43200', 'etag': 'W/"124-yiKdLzqO5gfBrJFrcdJ8Yq0LGnU"', 'expires': '-1', 'nel': '{"report_to":"heroku-nel","response_headers":["Via"],"max_age":3600,"success_fraction":0.01,"failure_fraction":0.1}', 'pragma': 'no-cache', 'report-to': '{"group":"heroku-nel","endpoints":[{"url":"https://nel.heroku.com/reports?s=23BefAR4K%2FU4iZ4IToD148XQADpZ2vBIxNANyCRbi6o%3D\\u0026sid=e11707d5-02a7-43ef-b45e-2cf4d2036f7d\\u0026ts=1775193861"}],"max_age":3600}', 'reporting-endpoints': 'heroku-nel="https://nel.heroku.com/reports?s=23BefAR4K%2FU4iZ4IToD148XQADpZ2vBIxNANyCRbi6o%3D&sid=e11707d5-02a7-43ef-b45e-2cf4d2036f7d&ts=1775193861"', 'server': 'cloudflare', 'vary': 'Origin, Accept-Encoding', 'via': '2.0 heroku-router', 'x-content-type-options': 'nosniff', 'x-powered-by': 'Express', 'x-ratelimit-limit': '1000', 'x-ratelimit-remaining': '999', 'x-ratelimit-reset': '1775193878', 'age': '21844', 'cf-cache-status': 'HIT', 'content-encoding': 'gzip', 'cf-ray': '9ed3f7157a74e173-MRS', 'alt-svc': 'h3=":443"; ma=86400'})

# %%
response.headers.get("transfer-encoding")
# Out:
# 'chunked'

# %%
response.headers.get("x-ratelimit-limit")
# Out:
# '1000'

# %%
response.headers.get("x-ratelimit-remaining")
# Out:
# '999'

# %%
response.headers.get("x-ratelimit-reset")
# Out:
# '1775193878'

# %%
response.headers.get("retry-after")

# %%
response.headers.get("set-cookie")

# %%
response.headers.get("x-content-type-options")
# Out:
# 'nosniff'

# %%
response.headers.get("strict-transport-security")

# %%
response.headers.get("content-security-policy")

# %%
response.headers.get("server")
# Out:
# 'cloudflare'

# %%
response.headers.get("via")
# Out:
# '2.0 heroku-router'

# %%
response.headers.get("x-powered-by")
# Out:
# 'Express'

# %%
response.headers.get("cf-ray")
# Out:
# '9ed3f7157a74e173-MRS'

# %%
response.headers.get("connection")
# Out:
# 'keep-alive'

# %%
response.headers.get("keep-alive")

# %%
response.headers.get("transfer-encoding")
# Out:
# 'chunked'
